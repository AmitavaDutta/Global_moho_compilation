# %%
import pandas as pd

# File path
path_to_data_file = r"D:\Amitava\Projects\Spline_Moho\Global_moho_compilation\Global_crust_raw.csv"

# Read full data
data_eq_raw = pd.read_csv(path_to_data_file, comment='#')

# Clean Moho_km
data_eq_raw["Moho_km"] = pd.to_numeric(data_eq_raw["Moho_km"], errors="coerce")
data_eq_all = data_eq_raw.dropna(subset=["Moho_km"]).reset_index(drop=True)

# Filter coordinates
data_eq_ind = data_eq_all[
    (data_eq_all["Long"] >= 65) & (data_eq_all["Long"] <= 110) &
    (data_eq_all["Lat"] >= 5) & (data_eq_all["Lat"] <= 45)
].reset_index(drop=True)

# Remove duplicate (Lat, Long, Moho_km)
data_eq_raw2 = data_eq_all.drop_duplicates(subset=["Lat", "Long", "Moho_km"], keep="first").reset_index(drop=True)

# Group by (Lat, Long)
grouped = data_eq_raw2.groupby(["Lat", "Long"])

filtered_rows = []
ambiguous_rows = []

for (lat, long), group in grouped:
    if len(group) == 1:
        filtered_rows.append(group.iloc[0])
    else:
        # Separate those with and without Avg_Vp/Vs
        with_vpvs = group.dropna(subset=["Avg_Vp/Vs"])
        without_vpvs = group[group["Avg_Vp/Vs"].isna()]

        if len(with_vpvs) == 1:
            filtered_rows.append(with_vpvs.iloc[0])
        elif len(with_vpvs) > 1:
            # Check for 'Hk' in comments among those with Vp/Vs
            hk_with_vpvs = with_vpvs[with_vpvs["Comments (Method - other notes etc.)"].str.contains("Hk", case=False, na=False)]
            if len(hk_with_vpvs) == 1:
                filtered_rows.append(hk_with_vpvs.iloc[0])
            else:
                ambiguous_rows.append(group)
        else:
            # No Vp/Vs available → check for 'Hk' among all
            hk_all = group[group["Comments (Method - other notes etc.)"].str.contains("Hk", case=False, na=False)]
            if len(hk_all) == 1:
                filtered_rows.append(hk_all.iloc[0])
            else:
                ambiguous_rows.append(group)

# Final cleaned dataframe
data_eq = pd.DataFrame(filtered_rows).reset_index(drop=True)

# Save cleaned data to CSV
data_eq.to_csv(r"D:\Amitava\Projects\Spline_Moho\Global_moho_compilation\Global_crust.csv", index=False)

# Ambiguous rows to CSV
if ambiguous_rows:
    ambiguous_df = pd.concat(ambiguous_rows).reset_index(drop=True)
    ambiguous_path = r"D:\Amitava\Projects\Spline_Moho\Global_moho_compilation\ambiguous_entries.csv"
    ambiguous_df.to_csv(ambiguous_path, index=False)
    print(f"Ambiguous entries saved to: {ambiguous_path} ({ambiguous_df.shape[0]} rows)")

print(f"Final cleaned data_eq rows: {data_eq.shape[0]}")

data_eq
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_21704\3730251536.py:7: DtypeWarning: Columns (0,1,4,5,6,7,8,12,13,14,19,20,21,23) have mixed types. Specify dtype option on import or set low_memory=False.
#   data_eq_raw = pd.read_csv(path_to_data_file, comment='#')
# Ambiguous entries saved to: D:\Amitava\Projects\Spline_Moho\Global_moho_compilation\ambiguous_entries.csv (4243 rows)
# Final cleaned data_eq rows: 28778
#        Net Station        Lat        Long  Moho_km err_moho Avg_Vp/Vs  \
# 0      NaN     NaN -90.000000    0.000000     38.0      NaN      1.83
# 1      NaN     NaN -90.000000  140.000000     26.0      NaN      1.63
# 2      NaN     NaN -89.930000  144.360000     40.0      NaN      1.73
# 3      NaN     NaN -89.930000  145.000000     39.0      NaN      1.76
# 4      NaN     NaN -87.420000 -149.430000     35.0      NaN      1.83
# ...    ...     ...        ...         ...      ...      ...       ...
# 28773  NaN     NaN  80.170000   18.730000     31.8      NaN         -
# 28774  NaN     NaN  80.768692   47.376292     31.0      NaN         -
# 28775  NaN     NaN  81.600000  -16.660000     32.0      NaN       1.8
# 28776  NaN     NaN  82.500000  -62.350000     25.0      NaN      1.81
# 28777  NaN     NaN  82.503300  -62.350000     29.0      NaN         -
#
#       Poisson’s_ratio Elevation  Avg_Vp(km/s)  ...      Compilation  \
# 0                 NaN       NaN           NaN  ...  Stephenson 2024
# 1                 NaN       NaN           NaN  ...  Stephenson 2024
# 2                 NaN       NaN           NaN  ...  Stephenson 2024
# 3                 NaN       NaN           NaN  ...  Stephenson 2024
# 4                 NaN       NaN           NaN  ...  Stephenson 2024
# ...               ...       ...           ...  ...              ...
# 28773             NaN       NaN           NaN  ...  Stephenson 2024
# 28774             NaN       NaN           NaN  ...  Stephenson 2024
# 28775             NaN       NaN           NaN  ...  Stephenson 2024
# 28776             NaN       NaN           NaN  ...  Stephenson 2024
# 28777             NaN       NaN           NaN  ...  Stephenson 2024
#
#        Comments (Method - other notes etc.)    Sub-methods Comments2  \
# 0                                        Hk            NaN       NaN
# 1                                        Hk            NaN       NaN
# 2                                        Hk            NaN       NaN
# 3                                        Hk            NaN       NaN
# 4                                        Hk            NaN       NaN
# ...                                     ...            ...       ...
# 28773                            Refraction     P_reversed       NaN
# 28774                              RF_other  forward_model       NaN
# 28775                                    Hk            NaN       NaN
# 28776                                    Hk            NaN       NaN
# 28777                              RF_other   RF_inversion       NaN
#
#       H2 (other methods) err Vsn2  κ2 Unnamed: 25 Unnamed: 26
# 0                    NaN NaN  NaN NaN         NaN         NaN
# 1                    NaN NaN  NaN NaN         NaN         NaN
# 2                    NaN NaN  NaN NaN         NaN         NaN
# 3                    NaN NaN  NaN NaN         NaN         NaN
# 4                    NaN NaN  NaN NaN         NaN         NaN
# ...                  ...  ..  ...  ..         ...         ...
# 28773                NaN NaN  NaN NaN         NaN         NaN
# 28774                NaN NaN  NaN NaN         NaN         NaN
# 28775                NaN NaN  NaN NaN         NaN         NaN
# 28776                NaN NaN  NaN NaN         NaN         NaN
# 28777                NaN NaN  NaN NaN         NaN         NaN
#
# [28778 rows x 27 columns]

# %%
# Split based on presence of 'Hk' in Comments
data_eq_hk = data_eq[data_eq["Comments (Method - other notes etc.)"].str.contains("Hk", case=False, na=False)].reset_index(drop=True)
data_eq_rest = data_eq[~data_eq["Comments (Method - other notes etc.)"].str.contains("Hk", case=False, na=False)].reset_index(drop=True)

# Optionally save to CSV
data_eq_hk.to_csv(r"D:\Amitava\Projects\Spline_Moho\Global_moho_compilation\Global_crust_Hk.csv", index=False)
data_eq_rest.to_csv(r"D:\Amitava\Projects\Spline_Moho\Global_moho_compilation\Global_crust_rest.csv", index=False)

# %%
data_eq_hk
# Out:
#        Net Station    Lat    Long  Moho_km err_moho Avg_Vp/Vs Poisson’s_ratio  \
# 0      NaN     NaN -90.00    0.00     38.0      NaN      1.83             NaN
# 1      NaN     NaN -90.00  140.00     26.0      NaN      1.63             NaN
# 2      NaN     NaN -89.93  144.36     40.0      NaN      1.73             NaN
# 3      NaN     NaN -89.93  145.00     39.0      NaN      1.76             NaN
# 4      NaN     NaN -87.42 -149.43     35.0      NaN      1.83             NaN
# ...    ...     ...    ...     ...      ...      ...       ...             ...
# 20879  NaN     NaN  78.92   11.94     27.0      NaN      1.75             NaN
# 20880  NaN     NaN  78.93   11.94     28.0      NaN      1.75             NaN
# 20881  NaN     NaN  80.05  -86.42     27.0      NaN       2.1             NaN
# 20882  NaN     NaN  81.60  -16.66     32.0      NaN       1.8             NaN
# 20883  NaN     NaN  82.50  -62.35     25.0      NaN      1.81             NaN
#
#       Elevation  Avg_Vp(km/s)  ...      Compilation  \
# 0           NaN           NaN  ...  Stephenson 2024
# 1           NaN           NaN  ...  Stephenson 2024
# 2           NaN           NaN  ...  Stephenson 2024
# 3           NaN           NaN  ...  Stephenson 2024
# 4           NaN           NaN  ...  Stephenson 2024
# ...         ...           ...  ...              ...
# 20879       NaN           NaN  ...  Stephenson 2024
# 20880       NaN           NaN  ...  Stephenson 2024
# 20881       NaN           NaN  ...  Stephenson 2024
# 20882       NaN           NaN  ...  Stephenson 2024
# 20883       NaN           NaN  ...  Stephenson 2024
#
#        Comments (Method - other notes etc.) Sub-methods Comments2  \
# 0                                        Hk         NaN       NaN
# 1                                        Hk         NaN       NaN
# 2                                        Hk         NaN       NaN
# 3                                        Hk         NaN       NaN
# 4                                        Hk         NaN       NaN
# ...                                     ...         ...       ...
# 20879                                    Hk         NaN       NaN
# 20880                                    Hk           -       NaN
# 20881                                    Hk         NaN       NaN
# 20882                                    Hk         NaN       NaN
# 20883                                    Hk         NaN       NaN
#
#       H2 (other methods) err Vsn2  κ2 Unnamed: 25 Unnamed: 26
# 0                    NaN NaN  NaN NaN         NaN         NaN
# 1                    NaN NaN  NaN NaN         NaN         NaN
# 2                    NaN NaN  NaN NaN         NaN         NaN
# 3                    NaN NaN  NaN NaN         NaN         NaN
# 4                    NaN NaN  NaN NaN         NaN         NaN
# ...                  ...  ..  ...  ..         ...         ...
# 20879                NaN NaN  NaN NaN         NaN         NaN
# 20880                NaN NaN  NaN NaN         NaN         NaN
# 20881                NaN NaN  NaN NaN         NaN         NaN
# 20882                NaN NaN  NaN NaN         NaN         NaN
# 20883                NaN NaN  NaN NaN         NaN         NaN
#
# [20884 rows x 27 columns]

# %%
data_eq_rest
# Out:
#       Net Station        Lat        Long  Moho_km err_moho Avg_Vp/Vs  \
# 0     NaN     NaN -82.120000 -115.800000    33.75      NaN         -
# 1     NaN     NaN -81.950000 -113.530000    31.50      NaN         -
# 2     NaN     NaN -81.370000 -107.280000    32.50      NaN         -
# 3     NaN     NaN -76.500000   15.000000    39.82      NaN         -
# 4     NaN     NaN -75.850000  161.400000    41.00      NaN         -
# ...   ...     ...        ...         ...      ...      ...       ...
# 7889  NaN     NaN  80.053300  -86.415800    34.00      NaN         -
# 7890  NaN     SQH  80.080000   32.500000    70.20      NaN      1.76
# 7891  NaN     NaN  80.170000   18.730000    31.80      NaN         -
# 7892  NaN     NaN  80.768692   47.376292    31.00      NaN         -
# 7893  NaN     NaN  82.503300  -62.350000    29.00      NaN         -
#
#      Poisson’s_ratio Elevation  Avg_Vp(km/s)  ...      Compilation  \
# 0                NaN       NaN           NaN  ...  Stephenson 2024
# 1                NaN       NaN           NaN  ...  Stephenson 2024
# 2                NaN       NaN           NaN  ...  Stephenson 2024
# 3                NaN       NaN           NaN  ...  Stephenson 2024
# 4                NaN       NaN           NaN  ...  Stephenson 2024
# ...              ...       ...           ...  ...              ...
# 7889             NaN       NaN           NaN  ...  Stephenson 2024
# 7890           0.262       NaN          6.47  ...       Singh 2015
# 7891             NaN       NaN           NaN  ...  Stephenson 2024
# 7892             NaN       NaN           NaN  ...  Stephenson 2024
# 7893             NaN       NaN           NaN  ...  Stephenson 2024
#
#       Comments (Method - other notes etc.)    Sub-methods Comments2  \
# 0                               Refraction     P_reversed       NaN
# 1                               Refraction   P_unreversed       NaN
# 2                               Refraction   P_unreversed       NaN
# 3                               Refraction     P_reversed       NaN
# 4                               Reflection              -       NaN
# ...                                    ...            ...       ...
# 7889                              RF_other   RF_inversion       NaN
# 7890                                   NaN            NaN       NaN
# 7891                            Refraction     P_reversed       NaN
# 7892                              RF_other  forward_model       NaN
# 7893                              RF_other   RF_inversion       NaN
#
#      H2 (other methods) err Vsn2  κ2 Unnamed: 25 Unnamed: 26
# 0                   NaN NaN  NaN NaN         NaN         NaN
# 1                   NaN NaN  NaN NaN         NaN         NaN
# 2                   NaN NaN  NaN NaN         NaN         NaN
# 3                   NaN NaN  NaN NaN         NaN         NaN
# 4                   NaN NaN  NaN NaN         NaN         NaN
# ...                 ...  ..  ...  ..         ...         ...
# 7889                NaN NaN  NaN NaN         NaN         NaN
# 7890                NaN NaN  NaN NaN         NaN         NaN
# 7891                NaN NaN  NaN NaN         NaN         NaN
# 7892                NaN NaN  NaN NaN         NaN         NaN
# 7893                NaN NaN  NaN NaN         NaN         NaN
#
# [7894 rows x 27 columns]
